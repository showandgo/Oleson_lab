# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read in excel files

# %%
dot_df = pd.read_excel("dot_hnl_roads.xls")

# %%
dot_df
# Out:
#        OBJECTID  year_recor  state_code route_id  begin_poin  end_point  \
# 0             1        2019          15   HI2P35       0.100      0.166
# 1             2        2019          15   HI2P35       0.166      0.183
# 2             3        2019          15       93       7.400      7.490
# 3             4        2019          15       93       7.490      7.500
# 4             5        2019          15       93      13.083     13.090
# ...         ...         ...         ...      ...         ...        ...
# 65530     65531        2019          15      930       4.431      4.465
# 65531     65532        2019          15      930       0.600      0.700
# 65532     65533        2019          15       19      88.200     88.300
# 65533     65534        2019          15       19      36.770     36.780
# 65534     65535        2019          15       11      88.100     88.200
#
#        f_system  urban_code  county_cod  route_numb  route_sign  \
# 0             7       89770           3           0          10
# 1             7       89770           3           0          10
# 2             3       89770           3          93           4
# 3             3       89770           3          93           4
# 4             3       89770           3          93           4
# ...         ...         ...         ...         ...         ...
# 65530         4       99998           3         930           4
# 65531         4       99999           3         930           4
# 65532         3       99998           1          19           4
# 65533         3       99999           1          19           4
# 65534         4       99999           1          11           4
#
#                                      alternativ  speed_limi  terrain_ty  \
# 0      Alakawa Street (Honolulu Harbor Pier 35)           0           1
# 1      Alakawa Street (Honolulu Harbor Pier 35)           0           1
# 2                            Farrington Highway          35           2
# 3                            Farrington Highway          35           2
# 4                            Farrington Highway          25           1
# ...                                         ...         ...         ...
# 65530                        Farrington Highway          45           1
# 65531                        Farrington Highway          45           1
# 65532                   Queen Kaahumanu Highway          55           2
# 65533                          Hawaii Belt Road          55           2
# 65534                         Mamalahoa Highway          55           3
#
#       widening_o  SHAPE__Len  Shape_Leng
# 0              A    0.001045  113.918507
# 1              A    0.000269   29.342661
# 2            AFG    0.001385  144.870529
# 3            DFG    0.000153   16.096705
# 4              A    0.000104   11.267835
# ...          ...         ...         ...
# 65530          X    0.000526   54.690719
# 65531         BF    0.001553  160.858245
# 65532          G    0.001484  160.787439
# 65533          D    0.000153   16.113928
# 65534          D    0.001455  161.112865
#
# [65535 rows x 17 columns]

# %% [markdown]
# ## Clean DOT State road data
# Try aggregating speeds (mean) for roads with same name

# %%
dot_df["speed_limi"].dtype
# Out:
# dtype('int64')

# %%
dot_df["speed_limi"].unique()
# Out:
# array([ 0, 35, 25, 55, 20, 30, 45, 15, 60, 50, 40,  5, 10])

# %%
# Filter out those rows without speed limit (speed limit = 0)

dot_spd = dot_df[dot_df["speed_limi"] != 0]
dot_spd.shape
# Out:
# (64520, 17)

# %%
# Save those with only one speed limit
# This is ready for join

dot_spd_rd1 = dot_spd[~dot_spd["alternativ"].duplicated(keep = False)]
dot_spd_rd1.shape
# Out:
# (1, 17)

# %%
dot_spd_rd1 = dot_spd_rd1[["alternativ", "speed_limi"]]    # Only road with no duplicates
dot_spd_rd1 = dot_spd_rd1.rename(columns = {"speed_limi" : "avg_spd"})

# %%
dot_spd_rd1 = dot_spd_rd1.rename(columns={"alternativ": "road_name"})

# %%
dot_spd_rd1
# Out:
#            road_name  avg_spd
# 21417  Pakini Street       55

# %%
# Grab rows with duplicate names

dot_spd_dupl = dot_spd[dot_spd["alternativ"].duplicated(keep = False)]
dot_spd_dupl.shape
# Out:
# (64519, 17)

# %%
# Number of unique names in the duplicated subset

len(dot_spd_dupl["alternativ"].unique())
# Out:
# 631

# %%
# Create new column that sums total length of particular road

dot_spd_dupl["tot_len"] = dot_spd_dupl.groupby("alternativ")["Shape_Leng"].transform("sum")
# Out:
# /var/folders/7z/bh_vxcz94c17ntk9rz3rrq3h0000gn/T/ipykernel_12553/2156704658.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dot_spd_dupl["tot_len"] = dot_spd_dupl.groupby("alternativ")["Shape_Leng"].transform("sum")

# %%
# Check Farrington Highway example

dot_spd_dupl[dot_spd_dupl["alternativ"] == "Farrington Highway"]
# Out:
#        OBJECTID  year_recor  state_code route_id  begin_poin  end_point  \
# 2             3        2019          15       93       7.400      7.490
# 3             4        2019          15       93       7.490      7.500
# 4             5        2019          15       93      13.083     13.090
# 5             6        2019          15       93       6.450      6.500
# 22           23        2019          15       93      18.900     18.990
# ...         ...         ...         ...      ...         ...        ...
# 65519     65520        2019          15       93      15.900     16.000
# 65520     65521        2019          15       93       4.062      4.080
# 65529     65530        2019          15      930       1.838      1.840
# 65530     65531        2019          15      930       4.431      4.465
# 65531     65532        2019          15      930       0.600      0.700
#
#        f_system  urban_code  county_cod  route_numb  route_sign  \
# 2             3       89770           3          93           4
# 3             3       89770           3          93           4
# 4             3       89770           3          93           4
# 5             3       89770           3          93           4
# 22            4       99999           3          93           4
# ...         ...         ...         ...         ...         ...
# 65519         3       89770           3          93           4
# 65520         3       89770           3          93           4
# 65529         4       99999           3         930           4
# 65530         4       99998           3         930           4
# 65531         4       99999           3         930           4
#
#                alternativ  speed_limi  terrain_ty widening_o  SHAPE__Len  \
# 2      Farrington Highway          35           2        AFG    0.001385
# 3      Farrington Highway          35           2        DFG    0.000153
# 4      Farrington Highway          25           1          A    0.000104
# 5      Farrington Highway          35           1        AFG    0.000752
# 22     Farrington Highway          25           3         DF    0.001363
# ...                   ...         ...         ...        ...         ...
# 65519  Farrington Highway          25           1         FG    0.001456
# 65520  Farrington Highway          35           2        DFG    0.000266
# 65529  Farrington Highway          45           1          B    0.000031
# 65530  Farrington Highway          45           1          X    0.000526
# 65531  Farrington Highway          45           1         BF    0.001553
#
#        Shape_Leng      tot_len
# 2      144.870529  48096.66842
# 3       16.096705  48096.66842
# 4       11.267835  48096.66842
# 5       80.483364  48096.66842
# 22     144.872760  48096.66842
# ...           ...          ...
# 65519  160.969819  48096.66842
# 65520   28.973844  48096.66842
# 65529    3.217105  48096.66842
# 65530   54.690719  48096.66842
# 65531  160.858245  48096.66842
#
# [1472 rows x 18 columns]

# %%
# Verify Sum operation works (yes)

dot_spd_dupl[dot_spd_dupl["alternativ"] == "Farrington Highway"]["Shape_Leng"].sum()
# Out:
# 48096.66842042876

# %%
dot_spd_dupl["agg_spd"] = (dot_spd_dupl["speed_limi"] * dot_spd_dupl["Shape_Leng"]) / dot_spd_dupl["tot_len"]
dot_spd_dupl["avg_spd"] = dot_spd_dupl.groupby("alternativ")["agg_spd"].transform("sum")
# Out:
# /var/folders/7z/bh_vxcz94c17ntk9rz3rrq3h0000gn/T/ipykernel_12553/3548215244.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dot_spd_dupl["agg_spd"] = (dot_spd_dupl["speed_limi"] * dot_spd_dupl["Shape_Leng"]) / dot_spd_dupl["tot_len"]

# %%
dot_spd_rd2 = dot_spd_dupl[["alternativ", "avg_spd"]].drop_duplicates()
dot_spd_rd2 = dot_spd_rd2.rename(columns={"alternativ": "road_name"})

# %%
dot_spd_rd2
# Out:
#                                    road_name    avg_spd
# 2                         Farrington Highway  33.640771
# 6                     Joseph P Leong Highway  43.177286
# 7                         Kamehameha Highway  35.413415
# 8                               Front Street  20.696062
# 9                       Kapoho Kalapana Road  30.846234
# ...                                      ...        ...
# 49868  Pier 2 access road (Port of Kawaihae)  48.999974
# 52858                               Kao Road  35.000000
# 54249                               H-1_WB_7  55.000000
# 58000                          Saratoga Road  45.000000
# 65184     Ala Luina Street (Port of Kahului)   7.010062
#
# [631 rows x 2 columns]

# %%
dot_spd_comb = pd.concat([dot_spd_rd2, dot_spd_rd1])
dot_spd_comb
# Out:
#                                 road_name    avg_spd
# 2                      Farrington Highway  33.640771
# 6                  Joseph P Leong Highway  43.177286
# 7                      Kamehameha Highway  35.413415
# 8                            Front Street  20.696062
# 9                    Kapoho Kalapana Road  30.846234
# ...                                   ...        ...
# 52858                            Kao Road  35.000000
# 54249                            H-1_WB_7  55.000000
# 58000                       Saratoga Road  45.000000
# 65184  Ala Luina Street (Port of Kahului)   7.010062
# 21417                       Pakini Street  55.000000
#
# [632 rows x 2 columns]

# %%
# Get rid of one NA row
dot_spd_notna = dot_spd_comb[~dot_spd_comb["road_name"].isna()]

# %%
dot_spd_notna.to_csv("dot_spd_comb.csv", index= False)

# %% [markdown]
# ## Experimental

# %%
cmn_name = ["Farrington"]

# %%
mask = df["fullname"].apply(lambda x: any(item for item in cmn_name if item in x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [224], in <module>
# ----> 1 mask = df["fullname"].apply(lambda x: any(item for item in cmn_name if item in x))
#
# File ~/miniforge3/envs/network/lib/python3.9/site-packages/pandas/core/series.py:4357, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4247 def apply(
#    4248     self,
#    4249     func: AggFuncType,
#    (...)
#    4252     **kwargs,
#    4253 ) -> FrameOrSeriesUnion:
#    4254     """
#    4255     Invoke function on values of Series.
#    4256
#    (...)
#    4355     dtype: float64
#    4356     """
# -> 4357     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/miniforge3/envs/network/lib/python3.9/site-packages/pandas/core/apply.py:1043, in SeriesApply.apply(self)
#    1039 if isinstance(self.f, str):
#    1040     # if we are a string, try to dispatch
#    1041     return self.apply_str()
# -> 1043 return self.apply_standard()
#
# File ~/miniforge3/envs/network/lib/python3.9/site-packages/pandas/core/apply.py:1098, in SeriesApply.apply_standard(self)
#    1092         values = obj.astype(object)._values
#    1093         # error: Argument 2 to "map_infer" has incompatible type
#    1094         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1095         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1096         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097         # "Callable[[Any], Any]"
# -> 1098         mapped = lib.map_infer(
#    1099             values,
#    1100             f,  # type: ignore[arg-type]
#    1101             convert=self.convert_dtype,
#    1102         )
#    1104 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1105     # GH 25959 use pd.array instead of tolist
#    1106     # so extension arrays can be used
#    1107     return obj._constructor_expanddim(pd_array(mapped), index=obj.index)
#
# File ~/miniforge3/envs/network/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2859, in pandas._libs.lib.map_infer()
#
# Input In [224], in <lambda>(x)
# ----> 1 mask = df["fullname"].apply(lambda x: any(item for item in cmn_name if item in x))
#
# Input In [224], in <genexpr>(.0)
# ----> 1 mask = df["fullname"].apply(lambda x: any(item for item in cmn_name if item in x))
#
# TypeError: argument of type 'float' is not iterable

# %%
df1 = df[mask]
df1
# Out:
#        objectid  segmentid        fullname class  street_cla  zipcoder  \
# 37           38       8882  FARRINGTON HWY   A21           8   96792.0
# 226         227       9954  FARRINGTON HWY   A21           8   96797.0
# 422         423       1009  FARRINGTON HWY   A21           8   96791.0
# 595         596       5854  FARRINGTON HWY   A21           8   96792.0
# 640         641       8288  FARRINGTON HWY   A25           8   96782.0
# ...         ...        ...             ...   ...         ...       ...
# 24743     24744      13800  FARRINGTON HWY   A21           8   96707.0
# 24766     24767      13778  FARRINGTON HWY   A21           8   96707.0
# 24792     24793      10396  FARRINGTON HWY   A21           8   96797.0
# 24839     24840       8532  FARRINGTON HWY   A21           8   96782.0
# 27042     27043      35300  FARRINGTON HWY   A41           4   96707.0
#
#        zipcodel       townl       townr                      neighborr  \
# 37      96792.0     Waianae     Waianae                        WAIANAE
# 226     96797.0     Waipahu     Waipahu                        WAIPAHU
# 422     96791.0     Waialua     Waialua                    NORTH SHORE
# 595     96792.0     Waianae     Waianae                        WAIANAE
# 640     96782.0  Pearl City  Pearl City                     PEARL CITY
# ...         ...         ...         ...                            ...
# 24743   96707.0     Waianae     Kapolei  MAKAKILO/KAPOLEI/HONOKAI HALE
# 24766   96707.0     Waianae     Kapolei  MAKAKILO/KAPOLEI/HONOKAI HALE
# 24792   96797.0   Ewa Beach   Ewa Beach                        WAIPAHU
# 24839   96782.0     Waipahu     Waipahu                        WAIPAHU
# 27042   96707.0     Kapolei     Kapolei  MAKAKILO/KAPOLEI/HONOKAI HALE
#
#        oneway  edittype revisedate    owner   loaddate  st_lengths  speed
# 37          0       NaN 2003-05-21    STATE 2009-05-15  440.395735      0
# 226         0       NaN 2003-05-21    STATE 2009-05-15   68.583003      0
# 422         0       NaN 2003-05-21    STATE 2009-05-15  351.295967      0
# 595         0       NaN 2003-05-21    STATE 2009-05-15   73.247810      0
# 640         0       NaN 2003-05-21  VARIOUS 2009-05-15  445.009136      0
# ...       ...       ...        ...      ...        ...         ...    ...
# 24743       0       NaN 2015-03-06    STATE 2015-03-06  235.429850      0
# 24766       0       NaN 2015-03-06    STATE 2015-03-06  911.608356      0
# 24792       1       NaN 2015-03-06    STATE 2015-03-06  111.850830      0
# 24839       1       NaN 2015-03-06  VARIOUS 2015-03-06   60.596824      0
# 27042       0       NaN 2020-05-22    STATE 2020-05-22   30.917278      0
#
# [214 rows x 17 columns]
